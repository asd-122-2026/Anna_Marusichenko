# %% [markdown]
# #Лабораторна робота № 2

# %% [markdown]
# ###Виконав: студент групи КН-25-1 Марусіченко А. О.

# %% [markdown]
# ##Тема. Налагоджування та робота в середовищі Anaconda+Quarto. Мета: швидкий старт для роботи в середовищі Anaconda із застосуванням Jupyter Notebook, або Jupyter Notebook засобами мови програмування Python та видавничої системи Quarto.

# %% [markdown]
# Порядок виконання роботи

# %% [markdown]
# 1. Завантажити і встановити збірку Python Anaconda.
# 2. Через інтерфейс командного рядка налагодити за допомогою conda віртуальне середовище з ім'ям _OpenCV. Етапи роботи підтвердити скріншотами. Використовується команда conda create -n Marusichenko_OpenCV python=3.11

# %% [markdown]
# ![Знімок екрана 2026-05-31 120453.png](attachment:aa3d7112-11af-4f9b-87bb-63569371f58a.png)

# %% [markdown]
# Рисунок 1 – Створення віртуального середовища

# %% [markdown]
# ![Знімок екрана 2026-05-31 220518.png](attachment:4a863ff3-316c-454f-bee9-574e71755818.png)

# %% [markdown]
# Рисунок 2 – Активація середовища

# %% [markdown]
# 3. Проінсталювати у створене середовище пакети, необхідні для роботи з OpenCV.

# %% [markdown]
# ![Знімок екрана 2026-05-31 221312.png](attachment:0db2c280-72f3-458c-9f55-f998885b8cc6.png)

# %% [markdown]
# Рисунок 3 – Проінстальовані пакети та встановлення Jupyter Notebook

# %% [markdown]
# 4. Створити Notebook-документ за допомогою Jupyter Notebook, або Jupyter Lab.

# %% [markdown]
# ![Знімок екрана 2026-05-31 120958.png](attachment:419e9867-9c2c-4067-bfaa-2d1eb7860c92.png)

# %% [markdown]
# Рисунок 4 – Створення Notebook-документа

# %% [markdown]
# 5. Скомпілювати звіт у форматі .html. Для цього необхідно завантажити термінал у робочому каталозі й у командному рядку запустити та таку команду: jupyter nbconvert lab_2_Marusichenko.ipynb --to html або, якщо наявна робота з налагодженим середовищем Quarto: quarto preview lab_2_Marusichenko.ipynb

# %% [markdown]
# ![Знімок екрана 2026-05-31 223428.png](attachment:da73e7a5-da88-4bfc-a7c6-420338a8b441.png)

# %% [markdown]
# Рисунок 5 – Звіт у формат .html

# %% [markdown]
# ##Контрольні питання

# %% [markdown]
# 1. Платформа Anaconda є базовим стандартом курсу для зручного керування науковими пакетами.
#
# 2. Окреме середовище потрібне кожному проєкту для уникнення конфліктів між версіями пакетів.
#
# 3. Базове оточення є загальним і глобальним, а проєктне — чистим і налаштованим під конкретну роботу.
#
# 4. Текстовий файл використовують для точного фіксування та відновлення всіх бібліотек оточення.
#
# 5. Шлях до інтерпретатора визначають командою where python або кодом import sys; print(sys.executable).
